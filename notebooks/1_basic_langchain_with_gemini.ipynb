# %% [markdown]
# #### Load Env Variables

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %% [markdown]
# #### Gemini api called

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

llm=ChatGoogleGenerativeAI(model="gemini-3.6-flash")

response = llm.invoke("who is pm of india")
response
# Out:
# AIMessage(content=[{'type': 'text', 'text': 'The Prime Minister of India is **Narendra Modi**. He has been in office since May 2014 and is currently serving his third consecutive term following the 2024 general elections.', 'extras': {'signature': '...'}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.6-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--01a06528-d276-7972-adb3-1a0051e7fba0-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 6, 'output_tokens': 252, 'total_tokens': 258, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 211}})

# %% [markdown]
# #### Static Prompt

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
llm=ChatGoogleGenerativeAI(model="gemini-3.6-flash")
prompts=[
    ("system","You are my Java Developer."),
    ("user","How to sort an array?")
]
res=llm.invoke(prompts)
print(res.content[0]["text"])
# Out:
# In Java, the simplest and most efficient way to sort an array is using the **`java.util.Arrays`** utility class.
#
# Here is a complete guide covering different scenarios:
#
# ---
#
# ### 1. Sorting Primitive Arrays (Ascending Order)
# To sort numbers or characters in ascending order, use `Arrays.sort()`.
#
# ```java
# import java.util.Arrays;
#
# public class SortExample {
#     public static void main(String[] args) {
#         int[] numbers = {5, 2, 8, 1, 3};
#
#         // Sorts the array in ascending order
#         Arrays.sort(numbers);
#
#         // Output: [1, 2, 3, 5, 8]
#         System.out.println(Arrays.toString(numbers));
#     }
# }
# ```
#
# ---
#
# ### 2. Sorting Objects / Strings
# `Arrays.sort()` works out-of-the-box for `String` arrays (alphabetical order) and standard Object wrapper classes (`Integer`, `Double`, etc.).
#
# ```java
# String[] names = {"Charlie", "Alice", "Bob"};
#
# Arrays.sort(names);
#
# // Output: [Alice, Bob, Charlie]
# System.out.println(Arrays.toString(names));
# ```
#
# ---
#
# ### 3. Sorting in Descending Order
# To sort in reverse order, use `Collections.reverseOrder()`.
#
# > **Note:** This requires **Wrapper Objects** (e.g., `Integer[]`) instead of primitives (`int[]`).
#
# ```java
# import java.util.Arrays;
# import java.util.Collections;
#
# public class SortExample {
#     public static void main(String[] args) {
#         Integer[] numbers = {5, 2, 8, 1, 3}; // Integer object, NOT int
#
#         Arrays.sort(numbers, Collections.reverseOrder());
#
#         // Output: [8, 5, 3, 2, 1]
#         System.out.println(Arrays.toString(numbers));
#     }
# }
# ```
#
# ---
#
# ### 4. Sorting Custom Objects (using `Comparator`)
# If you have an array of custom classes (e.g., `Employee`, `Student`), you can use a `Comparator` (Java 8+) to specify which field to sort by.
#
# ```java
# import java.util.Arrays;
# import java.util.Comparator;
#
# class Employee {
#     String name;
#     int age;
#
#     Employee(String name, int age) {
#         this.name = name;
#         this.age = age;
#     }
#
#     @Override
#     public String toString() {
#         return name + " (" + age + ")";
#     }
# }
#
# public class Main {
#     public static void main(String[] args) {
#         Employee[] employees = {
#             new Employee("Alice", 30),
#             new Employee("Bob", 22),
#             new Employee("Charlie", 25)
#         };
#
#         // Sort by Age (Ascending)
#         Arrays.sort(employees, Comparator.comparingInt(emp -> emp.age));
#
#         // Sort by Name (Alphabetical)
#         // Arrays.sort(employees, Comparator.comparing(emp -> emp.name));
#
#         System.out.println(Arrays.toString(employees));
#         // Output: [Bob (22), Charlie (25), Alice (30)]
#     }
# }
# ```
#
# ---
#
# ### 5. Sorting a Specific Range (Sub-array)
# You can sort only a part of an array by passing start and end indices (`fromIndex` is inclusive, `toIndex` is exclusive).
#
# ```java
# int[] numbers = {9, 5, 2, 8, 1, 3};
#
# // Sorts elements from index 1 to 4 (values: 5, 2, 8)
# Arrays.sort(numbers, 1, 4);
#
# // Output: [9, 2, 5, 8, 1, 3]
# System.out.println(Arrays.toString(numbers));
# ```
#
# ---
#
# ### 6. Performance Tip: Parallel Sort (For Large Arrays)
# If you are dealing with **very large arrays** (millions of elements), use `Arrays.parallelSort()`. It uses Java's ForkJoin pool to leverage multi-core processors for faster sorting.
#
# ```java
# int[] largeArray = { /* millions of integers */ };
#
# // Uses multi-threading for better performance
# Arrays.parallelSort(largeArray);
# ```
#
# ### Under the Hood Summary:
# * **Primitives:** Uses a **Dual-Pivot Quicksort** ($O(n \log n)$ time complexity).
# * **Objects:** Uses **Timsort** (an optimized hybrid of Merge Sort and Insertion Sort).
