# %%
from langchain_openai import ChatOpenAI

history=[]

llm=ChatOpenAI(model="gpt-5")

while True:
    query=input("User:")
    if query.lower() in ["quit"]:
        print("Bye")
        break
    
    history.append({"role":"user","content":query})
    print("User:", query)

    res=llm.invoke(history)
    history.append({"role":"ai","content":res.content})
    print("AI: ",res.content)
# Out:
# User:
# AI:  How can I help today? If you’re not sure, pick one:
# - Answer a question or explain a concept
# - Draft or edit an email, resume, or post
# - Summarize, outline, or fact-check an article
# - Brainstorm ideas (projects, names, content)
# - Solve or debug code/math problems
# - Plan a trip, study schedule, or workout
# - Translate or improve tone/clarity of writing
#
# Share any specifics you have: goal, audience, length, deadline, tools or format, and an example if available.
