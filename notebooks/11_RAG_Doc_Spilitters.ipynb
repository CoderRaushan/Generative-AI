# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

text="Generative artificial intelligence, commonly called Generative AI, refers to artificial intelligence systems that can create new content such as text, images, audio, video, and computer code. Modern generative AI systems are usually powered by large neural networks trained on very large collections of data. Large language models are a major category of generative AI models that specialize in understanding and generating natural language."


splitter=RecursiveCharacterTextSplitter(chunk_size=50,chunk_overlap=20)

chunks=splitter.split_text(text)
chunks

# %%
from langchain_community.document_loaders import TextLoader,PyPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter

textloader=TextLoader("../data/TextData.txt")
textData=textloader.load()

splitter=RecursiveCharacterTextSplitter(chunk_size=1000,chunk_overlap=200)

textChunks=splitter.split_documents(textData)
# textChunks

# textData

pdfloader=PyPDFLoader("../data/PdfData.pdf")
pdfData=pdfloader.load()

pdfChunks=splitter.split_documents(pdfData)
pdfChunks
