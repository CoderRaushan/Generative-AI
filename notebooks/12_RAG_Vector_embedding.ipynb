# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_openai import OpenAIEmbeddings   
documents=[
"Machine learning is a subset of artificial intelligence",
"Deep learning uses neural networks with multiple layers",
"Python is a programming language popular for data science",
"India won the cricket world cup in 2011",
"AI models can understand and generate human language"
]


embeddings=OpenAIEmbeddings(model="text-embedding-3-large")

vector=embeddings.embed_documents(documents)
vector

# %%
from langchain_chroma import Chroma
vector_store = Chroma.from_texts(
  texts=documents,
  embedding=embeddings,
  persist_directory="./vector_db"
)

# %%
query="Machine Learning"

result=vector_store.similarity_search(query=query,k=2)
result
# Out:
# [Document(id='922f3da3-394e-44ed-a63b-37f258c201cb', metadata={}, page_content='Machine learning is a subset of artificial intelligence'),
#  Document(id='1c6e1ac8-db5c-4ddf-bede-1cf4288b95f3', metadata={}, page_content='Machine learning is a subset of artificial intelligence')]
