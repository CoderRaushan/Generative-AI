# %%
from langchain_groq import ChatGroq
llm=ChatGroq(model="openai/gpt-oss-20b", streaming=True)
res=llm.stream("explain gen ai ?")
for chunk in res:
    print(chunk.content,end="")

# %%
from langchain_openai import ChatOpenAI
llm=ChatOpenAI(model="gpt-4", streaming=True)
res=llm.stream("explain gen ai ?")
for chunk in res:
    print(chunk.content,end="")
# Out:
# General AI, also known as Artificial General Intelligence (AGI), refers to a type of artificial intelligence that has the ability to understand, learn and apply its knowledge to a wide range of tasks. It's similar to human intelligence, which can carry out different types of tasks that require understanding and reasoning. Unlike Narrow AI, which is designed for a specific task like recommending songs or making online purchases, General AI can potentially perform any intellectual task that a human can do. As of now, AGI remains largely theoretical with no practical examples in use yet.
